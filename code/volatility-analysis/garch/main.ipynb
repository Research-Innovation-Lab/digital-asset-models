# %% [markdown]
# # GARCH (Generalized Autoregressive Conditional Heteroskedasticity)

# %% [markdown]
# The GARCH model is an econometric model that captures the time-varying volatility or variance of a time series. It assumes that the volatility of the series is autocorrelated and can be predicted based on past values of the series and past volatility.
#
# The basic form of the GARCH(p, q) model is:
#
# ```
# 𝜎_{𝑡}^2 = 𝜔 + 𝛼_{1}⋅𝜀_{𝑡−1}^2 + … + 𝛼_{𝑝}⋅𝜀_{𝑡−𝑝}^2 + 𝛽_{1}⋅𝜎_{𝑡−1}^2 + … + 𝛽_{𝑞}⋅𝜎_{𝑡−𝑞}^2
# ```
#
# Where:
#
# - \( 𝜎_{𝑡}^2 \) is the conditional variance at time \( 𝑡 \),
# - \( 𝜔 \) is the constant term,
# - \( 𝜀_{𝑡} \) is the error term at time \( 𝑡 \),
# - \( 𝛼_{𝑖} \) and \( 𝛽_{𝑖} \) are the coefficients for the squared error terms and the conditional variances at lag \( 𝑖 \) respectively,
# - \( 𝑝 \) and \( 𝑞 \) are the orders of the autoregressive and moving average terms respectively.

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import arch
import matplotlib.pyplot as plt
from arch.unitroot import ADF

# %%
# Define the cryptocurrencies
cryptos = ['BTC-USD', 'ETH-USD', 'SOL-USD', 'BNB-USD', 'XRP-USD', 'TON-USD', 'DOGE-USD', 'ADA-USD', 'SHIB-USD', 'AVAX-USD']

# Define the start and end dates
start_date = '2022-01-01'
end_date = '2024-01-01'

# Download data for the cryptocurrencies
data = yf.download(cryptos, start=start_date, end=end_date)
# Out:
# [*********************100%%**********************]  10 of 10 completed

# %%
# Close prices
prices = data['Adj Close']

# Calculate daily returns
returns = prices.pct_change().dropna()

# %%
# Fit GARCH model for each cryptocurrency
for crypto in cryptos:
    # Create GARCH model
    model = arch.arch_model(returns[crypto], vol='Garch', p=1, q=1)
    
    # Fit model
    results = model.fit()
    
    # Print summary
    print(f"\nSummary for {crypto}:")
    print(results.summary())
    
    # Plot volatility
    results.plot()
# Out:
# /Users/ephraim888sun/.pyenv/versions/3.9.6/lib/python3.9/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0008196. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/ephraim888sun/.pyenv/versions/3.9.6/lib/python3.9/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.001323. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/ephraim888sun/.pyenv/versions/3.9.6/lib/python3.9/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.003262. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/ephraim888sun/.pyenv/versions/3.9.6/lib/python3.9/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0009919. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/ephraim888sun/.pyenv/versions/3.9.6/lib/python3.9/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002187. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/ephraim888sun/.pyenv/versions/3.9.6/lib/python3.9/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.003209. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/ephraim888sun/.pyenv/versions/3.9.6/lib/python3.9/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002113. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/ephraim888sun/.pyenv/versions/3.9.6/lib/python3.9/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.001767. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 56549236.83898472
# Iteration:      2,   Func. Count:     17,   Neg. LLF: -993.2288890577365
# Iteration:      3,   Func. Count:     26,   Neg. LLF: -1507.6046925025457
# Iteration:      4,   Func. Count:     32,   Neg. LLF: 3897.2935991454483
# Iteration:      5,   Func. Count:     40,   Neg. LLF: -1580.0111164031407
# Iteration:      6,   Func. Count:     46,   Neg. LLF: -1588.2300668228236
# Iteration:      7,   Func. Count:     51,   Neg. LLF: -1588.236537345907
# Iteration:      8,   Func. Count:     56,   Neg. LLF: -1588.2371888365465
# Iteration:      9,   Func. Count:     61,   Neg. LLF: -1588.2371894797116
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1588.2371894797116
#             Iterations: 9
#             Function evaluations: 61
#             Gradient evaluations: 9
#
# Summary for BTC-USD:
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                BTC-USD   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:                1588.24
# Distribution:                  Normal   AIC:                          -3168.47
# Method:            Maximum Likelihood   BIC:                          -3150.11
#                                         No. Observations:                  729
# Date:                Thu, May 16 2024   Df Residuals:                      728
# Time:                        19:05:16   Df Model:                            1
#                                   Mean Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# mu         1.0926e-03  9.294e-04      1.176      0.240 [-7.289e-04,2.914e-03]
#                                Volatility Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# omega      2.7749e-04  1.550e-04      1.791  7.335e-02 [-2.623e-05,5.812e-04]
# alpha[1]       0.3161      0.229      1.383      0.167      [ -0.132,  0.764]
# beta[1]        0.3973      0.302      1.316      0.188      [ -0.194,  0.989]
# =============================================================================
#
# Covariance estimator: robust
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 1.2456723428955674e+17
# Iteration:      2,   Func. Count:     16,   Neg. LLF: -1444.2893753675999
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1444.2893799785506
#             Iterations: 6
#             Function evaluations: 16
#             Gradient evaluations: 2
#
# Summary for ETH-USD:
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                ETH-USD   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:                1444.29
# Distribution:                  Normal   AIC:                          -2880.58
# Method:            Maximum Likelihood   BIC:                          -2862.21
#                                         No. Observations:                  729
# Date:                Thu, May 16 2024   Df Residuals:                      728
# Time:                        19:05:17   Df Model:                            1
#                                   Mean Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# mu         6.4430e-04  1.014e-03      0.635      0.525 [-1.344e-03,2.632e-03]
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega      2.6458e-05  4.036e-06      6.555  5.559e-11 [1.855e-05,3.437e-05]
# alpha[1]       0.0500  1.765e-02      2.834  4.604e-03 [1.541e-02,8.459e-02]
# beta[1]        0.9300  1.508e-02     61.674      0.000     [  0.900,  0.960]
# ============================================================================
#
# Covariance estimator: robust
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 2065527.707611588
# Iteration:      2,   Func. Count:     17,   Neg. LLF: 1239.8843775186133
# Iteration:      3,   Func. Count:     25,   Neg. LLF: -1025.8549164635292
# Iteration:      4,   Func. Count:     32,   Neg. LLF: -1080.7291835063625
# Iteration:      5,   Func. Count:     38,   Neg. LLF: -944.9134301549
# Iteration:      6,   Func. Count:     45,   Neg. LLF: -1087.5246127064238
# Iteration:      7,   Func. Count:     51,   Neg. LLF: -1109.1189265464777
# Iteration:      8,   Func. Count:     57,   Neg. LLF: -1109.2787590294251
# Iteration:      9,   Func. Count:     62,   Neg. LLF: -1109.2791567524914
# Iteration:     10,   Func. Count:     67,   Neg. LLF: -1109.279142415799
# Iteration:     11,   Func. Count:     73,   Neg. LLF: -1109.2791588544696
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1109.279159335093
#             Iterations: 11
#             Function evaluations: 75
#             Gradient evaluations: 11
#
# Summary for SOL-USD:
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                SOL-USD   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:                1109.28
# Distribution:                  Normal   AIC:                          -2210.56
# Method:            Maximum Likelihood   BIC:                          -2192.19
#                                         No. Observations:                  729
# Date:                Thu, May 16 2024   Df Residuals:                      728
# Time:                        19:05:17   Df Model:                            1
#                                   Mean Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# mu         5.5646e-04  1.728e-03      0.322      0.747 [-2.831e-03,3.944e-03]
#                                Volatility Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# omega      2.8876e-04  1.814e-04      1.592      0.111 [-6.671e-05,6.442e-04]
# alpha[1]       0.1653  6.657e-02      2.484  1.300e-02    [3.486e-02,  0.296]
# beta[1]        0.7526      0.102      7.375  1.639e-13      [  0.553,  0.953]
# =============================================================================
#
# Covariance estimator: robust
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 216834731558.51816
# Iteration:      2,   Func. Count:     18,   Neg. LLF: 4266.54884811814
# Iteration:      3,   Func. Count:     27,   Neg. LLF: -1166.7430467326624
# Iteration:      4,   Func. Count:     35,   Neg. LLF: 1976706927.5529876
# Iteration:      5,   Func. Count:     46,   Neg. LLF: -1281.5689447809268
# Iteration:      6,   Func. Count:     54,   Neg. LLF: 557.6229419920012
# Iteration:      7,   Func. Count:     62,   Neg. LLF: -1388.958530860613
# Iteration:      8,   Func. Count:     69,   Neg. LLF: -995.4961315043089
# Iteration:      9,   Func. Count:     76,   Neg. LLF: -1545.259286447055
# Iteration:     10,   Func. Count:     82,   Neg. LLF: -1541.0318695035455
# Iteration:     11,   Func. Count:     89,   Neg. LLF: -1544.3962576257256
# Iteration:     12,   Func. Count:     95,   Neg. LLF: -1548.5208266260852
# Iteration:     13,   Func. Count:    101,   Neg. LLF: -1548.4950836981673
# Iteration:     14,   Func. Count:    107,   Neg. LLF: -1548.561859708091
# Iteration:     15,   Func. Count:    111,   Neg. LLF: -1548.5618597083821
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1548.561859708091
#             Iterations: 16
#             Function evaluations: 111
#             Gradient evaluations: 15
#
# Summary for BNB-USD:
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                BNB-USD   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:                1548.56
# Distribution:                  Normal   AIC:                          -3089.12
# Method:            Maximum Likelihood   BIC:                          -3070.76
#                                         No. Observations:                  729
# Date:                Thu, May 16 2024   Df Residuals:                      728
# Time:                        19:05:17   Df Model:                            1
#                                   Mean Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# mu         6.9448e-04  9.008e-04      0.771      0.441 [-1.071e-03,2.460e-03]
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega      7.3644e-05  2.822e-05      2.609  9.071e-03 [1.833e-05,1.290e-04]
# alpha[1]       0.2200  7.332e-02      3.000  2.696e-03   [7.629e-02,  0.364]
# beta[1]        0.7336  5.813e-02     12.621  1.613e-36     [  0.620,  0.848]
# ============================================================================
#
# Covariance estimator: robust
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 601862.2905694478
# Iteration:      2,   Func. Count:     17,   Neg. LLF: -666.7867935602271
# Iteration:      3,   Func. Count:     26,   Neg. LLF: -1070.9845545719231
# Iteration:      4,   Func. Count:     33,   Neg. LLF: -1205.3804828691345
# Iteration:      5,   Func. Count:     38,   Neg. LLF: -1205.4019433598223
# Iteration:      6,   Func. Count:     43,   Neg. LLF: -1205.4344401492947
# Iteration:      7,   Func. Count:     48,   Neg. LLF: -1205.4378186591944
# Iteration:      8,   Func. Count:     53,   Neg. LLF: -1205.4378524067838
# Iteration:      9,   Func. Count:     57,   Neg. LLF: -1205.4378523914093
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1205.4378524067838
#             Iterations: 9
#             Function evaluations: 57
#             Gradient evaluations: 9
#
# Summary for XRP-USD:
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                XRP-USD   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:                1205.44
# Distribution:                  Normal   AIC:                          -2402.88
# Method:            Maximum Likelihood   BIC:                          -2384.51
#                                         No. Observations:                  729
# Date:                Thu, May 16 2024   Df Residuals:                      728
# Time:                        19:05:17   Df Model:                            1
#                                   Mean Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# mu         1.2991e-03  1.639e-03      0.793      0.428 [-1.913e-03,4.511e-03]
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega      2.0209e-03  7.249e-04      2.788  5.307e-03 [6.001e-04,3.442e-03]
# alpha[1]       0.0931      0.112      0.829      0.407     [ -0.127,  0.313]
# beta[1]        0.0000      0.143      0.000      1.000     [ -0.280,  0.280]
# ============================================================================
#
# Covariance estimator: robust
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 179850832.59835985
# Iteration:      2,   Func. Count:     17,   Neg. LLF: 702.5924525916735
# Iteration:      3,   Func. Count:     27,   Neg. LLF: -578.0926590161591
# Iteration:      4,   Func. Count:     33,   Neg. LLF: -1206.496732274988
# Iteration:      5,   Func. Count:     38,   Neg. LLF: -1100.3596641884726
# Iteration:      6,   Func. Count:     44,   Neg. LLF: -1207.0641995166334
# Iteration:      7,   Func. Count:     49,   Neg. LLF: -1207.109497857679
# Iteration:      8,   Func. Count:     54,   Neg. LLF: -1207.1258355070377
# Iteration:      9,   Func. Count:     59,   Neg. LLF: -1207.1274984696404
# Iteration:     10,   Func. Count:     64,   Neg. LLF: -1207.1275036351217
# Iteration:     11,   Func. Count:     68,   Neg. LLF: -1207.127504080131
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1207.1275036351217
#             Iterations: 11
#             Function evaluations: 68
#             Gradient evaluations: 11
#
# Summary for TON-USD:
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                TON-USD   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:                1207.13
# Distribution:                  Normal   AIC:                          -2406.26
# Method:            Maximum Likelihood   BIC:                          -2387.89
#                                         No. Observations:                  729
# Date:                Thu, May 16 2024   Df Residuals:                      728
# Time:                        19:05:17   Df Model:                            1
#                                   Mean Model
# ==============================================================================
#                   coef    std err          t      P>|t|       95.0% Conf. Int.
# ------------------------------------------------------------------------------
# mu         -9.2064e-04  1.485e-03     -0.620      0.535 [-3.832e-03,1.990e-03]
#                                Volatility Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# omega      1.0402e-04  6.689e-05      1.555      0.120 [-2.708e-05,2.351e-04]
# alpha[1]       0.2093      0.108      1.940  5.241e-02   [-2.184e-03,  0.421]
# beta[1]        0.7907  9.091e-02      8.697  3.393e-18      [  0.613,  0.969]
# =============================================================================
#
# Covariance estimator: robust
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 58738.74202167407
# Iteration:      2,   Func. Count:     17,   Neg. LLF: -672.5924493715827
# Iteration:      3,   Func. Count:     26,   Neg. LLF: -1246.9269540896807
# Iteration:      4,   Func. Count:     32,   Neg. LLF: -1273.6088208101887
# Iteration:      5,   Func. Count:     38,   Neg. LLF: -1298.5403739824142
# Iteration:      6,   Func. Count:     44,   Neg. LLF: -1308.4241056243166
# Iteration:      7,   Func. Count:     50,   Neg. LLF: -1308.5661815918352
# Iteration:      8,   Func. Count:     55,   Neg. LLF: -1308.566458019373
# Iteration:      9,   Func. Count:     60,   Neg. LLF: -1308.5664606729774
# Iteration:     10,   Func. Count:     64,   Neg. LLF: -1308.5664606729997
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1308.5664606729774
#             Iterations: 10
#             Function evaluations: 64
#             Gradient evaluations: 10
#
# Summary for DOGE-USD:
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:               DOGE-USD   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:                1308.57
# Distribution:                  Normal   AIC:                          -2609.13
# Method:            Maximum Likelihood   BIC:                          -2590.77
#                                         No. Observations:                  729
# Date:                Thu, May 16 2024   Df Residuals:                      728
# Time:                        19:05:17   Df Model:                            1
#                                   Mean Model
# ==============================================================================
#                   coef    std err          t      P>|t|       95.0% Conf. Int.
# ------------------------------------------------------------------------------
# mu         -9.5753e-05  1.439e-03 -6.656e-02      0.947 [-2.915e-03,2.724e-03]
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega      4.4731e-04  1.497e-04      2.988  2.804e-03 [1.539e-04,7.407e-04]
# alpha[1]       0.3992      0.145      2.757  5.841e-03     [  0.115,  0.683]
# beta[1]        0.4349      0.120      3.635  2.782e-04     [  0.200,  0.669]
# ============================================================================
#
# Covariance estimator: robust
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 318908383.22364813
# Iteration:      2,   Func. Count:     17,   Neg. LLF: 1243.4499897656658
# Iteration:      3,   Func. Count:     26,   Neg. LLF: 6931.3345620784485
# /Users/ephraim888sun/.pyenv/versions/3.9.6/lib/python3.9/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.003173. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/ephraim888sun/.pyenv/versions/3.9.6/lib/python3.9/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002611. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Iteration:      4,   Func. Count:     36,   Neg. LLF: -1247.1211035384517
# Iteration:      5,   Func. Count:     43,   Neg. LLF: -1236.259444872119
# Iteration:      6,   Func. Count:     50,   Neg. LLF: -1196.3583372165247
# Iteration:      7,   Func. Count:     56,   Neg. LLF: -1321.1723520069502
# Iteration:      8,   Func. Count:     61,   Neg. LLF: -1321.1723914379838
# Iteration:      9,   Func. Count:     66,   Neg. LLF: -1321.172393596839
# Iteration:     10,   Func. Count:     70,   Neg. LLF: -1321.1723935967202
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1321.172393596839
#             Iterations: 10
#             Function evaluations: 70
#             Gradient evaluations: 10
#
# Summary for ADA-USD:
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                ADA-USD   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:                1321.17
# Distribution:                  Normal   AIC:                          -2634.34
# Method:            Maximum Likelihood   BIC:                          -2615.98
#                                         No. Observations:                  729
# Date:                Thu, May 16 2024   Df Residuals:                      728
# Time:                        19:05:17   Df Model:                            1
#                                   Mean Model
# ==============================================================================
#                   coef    std err          t      P>|t|       95.0% Conf. Int.
# ------------------------------------------------------------------------------
# mu         -1.0898e-04  1.418e-03 -7.686e-02      0.939 [-2.888e-03,2.670e-03]
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega      2.4967e-04  1.267e-04      1.970  4.885e-02 [1.258e-06,4.981e-04]
# alpha[1]       0.1949  7.757e-02      2.513  1.197e-02   [4.290e-02,  0.347]
# beta[1]        0.6779  7.420e-02      9.136  6.457e-20     [  0.532,  0.823]
# ============================================================================
#
# Covariance estimator: robust
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 2324349.4722213494
# Iteration:      2,   Func. Count:     17,   Neg. LLF: 1453.1088292219497
# Iteration:      3,   Func. Count:     25,   Neg. LLF: -1057.523787921562
# Iteration:      4,   Func. Count:     31,   Neg. LLF: -1085.2256979356769
# Iteration:      5,   Func. Count:     37,   Neg. LLF: -1085.7769010066806
# Iteration:      6,   Func. Count:     43,   Neg. LLF: -1086.1968665588115
# Iteration:      7,   Func. Count:     48,   Neg. LLF: -1086.2020938414612
# Iteration:      8,   Func. Count:     53,   Neg. LLF: -1086.2021170989049
# Iteration:      9,   Func. Count:     57,   Neg. LLF: -1086.2021170986322
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1086.2021170989049
#             Iterations: 9
#             Function evaluations: 57
#             Gradient evaluations: 9
#
# Summary for SHIB-USD:
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:               SHIB-USD   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:                1086.20
# Distribution:                  Normal   AIC:                          -2164.40
# Method:            Maximum Likelihood   BIC:                          -2146.04
#                                         No. Observations:                  729
# Date:                Thu, May 16 2024   Df Residuals:                      728
# Time:                        19:05:17   Df Model:                            1
#                                   Mean Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# mu         3.6694e-04  1.837e-03      0.200      0.842 [-3.234e-03,3.968e-03]
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega      2.0985e-03  6.596e-04      3.182  1.464e-03 [8.058e-04,3.391e-03]
# alpha[1]       0.2029  6.539e-02      3.104  1.910e-03   [7.479e-02,  0.331]
# beta[1]        0.1431      0.190      0.753      0.452     [ -0.229,  0.516]
# ============================================================================
#
# Covariance estimator: robust
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 42198409.20193264
# Iteration:      2,   Func. Count:     17,   Neg. LLF: 3920.634512606465
# Iteration:      3,   Func. Count:     24,   Neg. LLF: -1146.8126006056455
# Iteration:      4,   Func. Count:     31,   Neg. LLF: -618.6571516928296
# Iteration:      5,   Func. Count:     37,   Neg. LLF: -1190.0509564781207
# Iteration:      6,   Func. Count:     43,   Neg. LLF: -1197.9359444203628
# Iteration:      7,   Func. Count:     49,   Neg. LLF: -1171.9453244742308
# Iteration:      8,   Func. Count:     55,   Neg. LLF: -1198.2107239255693
# Iteration:      9,   Func. Count:     61,   Neg. LLF: -1198.7009146984797
# Iteration:     10,   Func. Count:     67,   Neg. LLF: -1198.7545666637898
# Iteration:     11,   Func. Count:     72,   Neg. LLF: -1198.7556268794883
# Iteration:     12,   Func. Count:     77,   Neg. LLF: -1198.755626571609
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1198.7556269628533
#             Iterations: 12
#             Function evaluations: 78
#             Gradient evaluations: 12
#
# Summary for AVAX-USD:
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:               AVAX-USD   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:                1198.76
# Distribution:                  Normal   AIC:                          -2389.51
# Method:            Maximum Likelihood   BIC:                          -2371.14
#                                         No. Observations:                  729
# Date:                Thu, May 16 2024   Df Residuals:                      728
# Time:                        19:05:17   Df Model:                            1
#                                   Mean Model
# ==============================================================================
#                   coef    std err          t      P>|t|       95.0% Conf. Int.
# ------------------------------------------------------------------------------
# mu         -2.2635e-03  1.570e-03     -1.442      0.149 [-5.340e-03,8.133e-04]
#                                Volatility Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# omega      1.3697e-04  8.238e-05      1.663  9.639e-02 [-2.450e-05,2.984e-04]
# alpha[1]       0.2393  8.402e-02      2.848  4.400e-03    [7.461e-02,  0.404]
# beta[1]        0.7411  7.149e-02     10.366  3.528e-25      [  0.601,  0.881]
# =============================================================================
#
# Covariance estimator: robust

# %%
# Initialize a plot
plt.figure(figsize=(12, 8))

# Iterate over each cryptocurrency
for crypto in cryptos:
    # Create GARCH model
    model = arch.arch_model(returns[crypto], vol='Garch', p=1, q=1)
    
    # Fit model
    results = model.fit()
    
    # Plot volatility forecast
    plt.plot(results.conditional_volatility, label=crypto)

# Add labels and legend
plt.title('GARCH Volatility Forecast Comparison')
plt.xlabel('Date')
plt.ylabel('Volatility')
plt.legend()

# Show plot
plt.show()
# Out:
# /Users/ephraim888sun/.pyenv/versions/3.9.6/lib/python3.9/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0008196. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/ephraim888sun/.pyenv/versions/3.9.6/lib/python3.9/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.001323. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/ephraim888sun/.pyenv/versions/3.9.6/lib/python3.9/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.003262. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/ephraim888sun/.pyenv/versions/3.9.6/lib/python3.9/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0009919. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/ephraim888sun/.pyenv/versions/3.9.6/lib/python3.9/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002187. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/ephraim888sun/.pyenv/versions/3.9.6/lib/python3.9/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.003209. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/ephraim888sun/.pyenv/versions/3.9.6/lib/python3.9/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002113. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/ephraim888sun/.pyenv/versions/3.9.6/lib/python3.9/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.001767. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/ephraim888sun/.pyenv/versions/3.9.6/lib/python3.9/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.003173. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/ephraim888sun/.pyenv/versions/3.9.6/lib/python3.9/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002611. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 56549236.83898472
# Iteration:      2,   Func. Count:     17,   Neg. LLF: -993.2288890577365
# Iteration:      3,   Func. Count:     26,   Neg. LLF: -1507.6046925025457
# Iteration:      4,   Func. Count:     32,   Neg. LLF: 3897.2935991454483
# Iteration:      5,   Func. Count:     40,   Neg. LLF: -1580.0111164031407
# Iteration:      6,   Func. Count:     46,   Neg. LLF: -1588.2300668228236
# Iteration:      7,   Func. Count:     51,   Neg. LLF: -1588.236537345907
# Iteration:      8,   Func. Count:     56,   Neg. LLF: -1588.2371888365465
# Iteration:      9,   Func. Count:     61,   Neg. LLF: -1588.2371894797116
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1588.2371894797116
#             Iterations: 9
#             Function evaluations: 61
#             Gradient evaluations: 9
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 1.2456723428955674e+17
# Iteration:      2,   Func. Count:     16,   Neg. LLF: -1444.2893753675999
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1444.2893799785506
#             Iterations: 6
#             Function evaluations: 16
#             Gradient evaluations: 2
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 2065527.707611588
# Iteration:      2,   Func. Count:     17,   Neg. LLF: 1239.8843775186133
# Iteration:      3,   Func. Count:     25,   Neg. LLF: -1025.8549164635292
# Iteration:      4,   Func. Count:     32,   Neg. LLF: -1080.7291835063625
# Iteration:      5,   Func. Count:     38,   Neg. LLF: -944.9134301549
# Iteration:      6,   Func. Count:     45,   Neg. LLF: -1087.5246127064238
# Iteration:      7,   Func. Count:     51,   Neg. LLF: -1109.1189265464777
# Iteration:      8,   Func. Count:     57,   Neg. LLF: -1109.2787590294251
# Iteration:      9,   Func. Count:     62,   Neg. LLF: -1109.2791567524914
# Iteration:     10,   Func. Count:     67,   Neg. LLF: -1109.279142415799
# Iteration:     11,   Func. Count:     73,   Neg. LLF: -1109.2791588544696
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1109.279159335093
#             Iterations: 11
#             Function evaluations: 75
#             Gradient evaluations: 11
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 216834731558.51816
# Iteration:      2,   Func. Count:     18,   Neg. LLF: 4266.54884811814
# Iteration:      3,   Func. Count:     27,   Neg. LLF: -1166.7430467326624
# Iteration:      4,   Func. Count:     35,   Neg. LLF: 1976706927.5529876
# Iteration:      5,   Func. Count:     46,   Neg. LLF: -1281.5689447809268
# Iteration:      6,   Func. Count:     54,   Neg. LLF: 557.6229419920012
# Iteration:      7,   Func. Count:     62,   Neg. LLF: -1388.958530860613
# Iteration:      8,   Func. Count:     69,   Neg. LLF: -995.4961315043089
# Iteration:      9,   Func. Count:     76,   Neg. LLF: -1545.259286447055
# Iteration:     10,   Func. Count:     82,   Neg. LLF: -1541.0318695035455
# Iteration:     11,   Func. Count:     89,   Neg. LLF: -1544.3962576257256
# Iteration:     12,   Func. Count:     95,   Neg. LLF: -1548.5208266260852
# Iteration:     13,   Func. Count:    101,   Neg. LLF: -1548.4950836981673
# Iteration:     14,   Func. Count:    107,   Neg. LLF: -1548.561859708091
# Iteration:     15,   Func. Count:    111,   Neg. LLF: -1548.5618597083821
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1548.561859708091
#             Iterations: 16
#             Function evaluations: 111
#             Gradient evaluations: 15
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 601862.2905694478
# Iteration:      2,   Func. Count:     17,   Neg. LLF: -666.7867935602271
# Iteration:      3,   Func. Count:     26,   Neg. LLF: -1070.9845545719231
# Iteration:      4,   Func. Count:     33,   Neg. LLF: -1205.3804828691345
# Iteration:      5,   Func. Count:     38,   Neg. LLF: -1205.4019433598223
# Iteration:      6,   Func. Count:     43,   Neg. LLF: -1205.4344401492947
# Iteration:      7,   Func. Count:     48,   Neg. LLF: -1205.4378186591944
# Iteration:      8,   Func. Count:     53,   Neg. LLF: -1205.4378524067838
# Iteration:      9,   Func. Count:     57,   Neg. LLF: -1205.4378523914093
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1205.4378524067838
#             Iterations: 9
#             Function evaluations: 57
#             Gradient evaluations: 9
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 179850832.59835985
# Iteration:      2,   Func. Count:     17,   Neg. LLF: 702.5924525916735
# Iteration:      3,   Func. Count:     27,   Neg. LLF: -578.0926590161591
# Iteration:      4,   Func. Count:     33,   Neg. LLF: -1206.496732274988
# Iteration:      5,   Func. Count:     38,   Neg. LLF: -1100.3596641884726
# Iteration:      6,   Func. Count:     44,   Neg. LLF: -1207.0641995166334
# Iteration:      7,   Func. Count:     49,   Neg. LLF: -1207.109497857679
# Iteration:      8,   Func. Count:     54,   Neg. LLF: -1207.1258355070377
# Iteration:      9,   Func. Count:     59,   Neg. LLF: -1207.1274984696404
# Iteration:     10,   Func. Count:     64,   Neg. LLF: -1207.1275036351217
# Iteration:     11,   Func. Count:     68,   Neg. LLF: -1207.127504080131
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1207.1275036351217
#             Iterations: 11
#             Function evaluations: 68
#             Gradient evaluations: 11
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 58738.74202167407
# Iteration:      2,   Func. Count:     17,   Neg. LLF: -672.5924493715827
# Iteration:      3,   Func. Count:     26,   Neg. LLF: -1246.9269540896807
# Iteration:      4,   Func. Count:     32,   Neg. LLF: -1273.6088208101887
# Iteration:      5,   Func. Count:     38,   Neg. LLF: -1298.5403739824142
# Iteration:      6,   Func. Count:     44,   Neg. LLF: -1308.4241056243166
# Iteration:      7,   Func. Count:     50,   Neg. LLF: -1308.5661815918352
# Iteration:      8,   Func. Count:     55,   Neg. LLF: -1308.566458019373
# Iteration:      9,   Func. Count:     60,   Neg. LLF: -1308.5664606729774
# Iteration:     10,   Func. Count:     64,   Neg. LLF: -1308.5664606729997
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1308.5664606729774
#             Iterations: 10
#             Function evaluations: 64
#             Gradient evaluations: 10
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 318908383.22364813
# Iteration:      2,   Func. Count:     17,   Neg. LLF: 1243.4499897656658
# Iteration:      3,   Func. Count:     26,   Neg. LLF: 6931.3345620784485
# Iteration:      4,   Func. Count:     36,   Neg. LLF: -1247.1211035384517
# Iteration:      5,   Func. Count:     43,   Neg. LLF: -1236.259444872119
# Iteration:      6,   Func. Count:     50,   Neg. LLF: -1196.3583372165247
# Iteration:      7,   Func. Count:     56,   Neg. LLF: -1321.1723520069502
# Iteration:      8,   Func. Count:     61,   Neg. LLF: -1321.1723914379838
# Iteration:      9,   Func. Count:     66,   Neg. LLF: -1321.172393596839
# Iteration:     10,   Func. Count:     70,   Neg. LLF: -1321.1723935967202
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1321.172393596839
#             Iterations: 10
#             Function evaluations: 70
#             Gradient evaluations: 10
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 2324349.4722213494
# Iteration:      2,   Func. Count:     17,   Neg. LLF: 1453.1088292219497
# Iteration:      3,   Func. Count:     25,   Neg. LLF: -1057.523787921562
# Iteration:      4,   Func. Count:     31,   Neg. LLF: -1085.2256979356769
# Iteration:      5,   Func. Count:     37,   Neg. LLF: -1085.7769010066806
# Iteration:      6,   Func. Count:     43,   Neg. LLF: -1086.1968665588115
# Iteration:      7,   Func. Count:     48,   Neg. LLF: -1086.2020938414612
# Iteration:      8,   Func. Count:     53,   Neg. LLF: -1086.2021170989049
# Iteration:      9,   Func. Count:     57,   Neg. LLF: -1086.2021170986322
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1086.2021170989049
#             Iterations: 9
#             Function evaluations: 57
#             Gradient evaluations: 9
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 42198409.20193264
# Iteration:      2,   Func. Count:     17,   Neg. LLF: 3920.634512606465
# Iteration:      3,   Func. Count:     24,   Neg. LLF: -1146.8126006056455
# Iteration:      4,   Func. Count:     31,   Neg. LLF: -618.6571516928296
# Iteration:      5,   Func. Count:     37,   Neg. LLF: -1190.0509564781207
# Iteration:      6,   Func. Count:     43,   Neg. LLF: -1197.9359444203628
# Iteration:      7,   Func. Count:     49,   Neg. LLF: -1171.9453244742308
# Iteration:      8,   Func. Count:     55,   Neg. LLF: -1198.2107239255693
# Iteration:      9,   Func. Count:     61,   Neg. LLF: -1198.7009146984797
# Iteration:     10,   Func. Count:     67,   Neg. LLF: -1198.7545666637898
# Iteration:     11,   Func. Count:     72,   Neg. LLF: -1198.7556268794883
# Iteration:     12,   Func. Count:     77,   Neg. LLF: -1198.755626571609
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1198.7556269628533
#             Iterations: 12
#             Function evaluations: 78
#             Gradient evaluations: 12

# %% [markdown]
# ## Metrics

# %%
# Fit GARCH model for each cryptocurrency
aic_values = {}
bic_values = {}
residuals_std = {}
adf_pvalues = {}
forecast_errors = {}

for crypto in cryptos:
    # Create GARCH model
    model = arch.arch_model(returns[crypto], vol='Garch', p=1, q=1)
    
    # Fit model
    results = model.fit(disp='off')
    
    # Calculate AIC and BIC
    aic_values[crypto] = results.aic
    bic_values[crypto] = results.bic
    
    # Residual analysis
    residuals = results.resid
    residuals_std[crypto] = residuals.std()
    
    # Augmented Dickey-Fuller test for residual stationarity
    adf_test = ADF(residuals)
    adf_pvalues[crypto] = adf_test.pvalue
    
    # Out-of-sample forecasting
    forecast = results.forecast(horizon=1)
    forecast_errors[crypto] = forecast.variance.iloc[-1] - returns[crypto][-1]**2

# Display results
print("AIC Values:")
print(aic_values)
print("\nBIC Values:")
print(bic_values)
print("\nStandard Deviation of Residuals:")
print(residuals_std)
print("\nAugmented Dickey-Fuller Test p-values:")
print(adf_pvalues)
print("\nForecast Errors:")
print(forecast_errors)
# Out:
# AIC Values:
# {'BTC-USD': -3168.474378959423, 'ETH-USD': -2880.5787599571013, 'SOL-USD': -2210.558318670186, 'BNB-USD': -3089.123719416182, 'XRP-USD': -2402.8757048135676, 'TON-USD': -2406.2550072702434, 'DOGE-USD': -2609.132921345955, 'ADA-USD': -2634.344787193678, 'SHIB-USD': -2164.4042341978097, 'AVAX-USD': -2389.5112539257066}
#
# BIC Values:
# {'BTC-USD': -3150.1076840313885, 'ETH-USD': -2862.2120650290667, 'SOL-USD': -2192.1916237421515, 'BNB-USD': -3070.7570244881476, 'XRP-USD': -2384.509009885533, 'TON-USD': -2387.888312342209, 'DOGE-USD': -2590.7662264179203, 'ADA-USD': -2615.978092265643, 'SHIB-USD': -2146.037539269775, 'AVAX-USD': -2371.144558997672}
#
# Standard Deviation of Residuals:
# {'BTC-USD': 0.02864873654876747, 'ETH-USD': 0.03639676492050969, 'SOL-USD': 0.05715278817860063, 'BNB-USD': 0.031515462333268095, 'XRP-USD': 0.04679767763907259, 'TON-USD': 0.05668299209820322, 'DOGE-USD': 0.04600218641756881, 'ADA-USD': 0.04206990824873659, 'SHIB-USD': 0.056366440048687134, 'AVAX-USD': 0.05113152695733308}
#
# Augmented Dickey-Fuller Test p-values:
# {'BTC-USD': 0.0, 'ETH-USD': 1.087440653928244e-14, 'SOL-USD': 5.119590509280446e-13, 'BNB-USD': 0.0, 'XRP-USD': 0.0, 'TON-USD': 5.5280019262585686e-17, 'DOGE-USD': 2.3842721929472458e-11, 'ADA-USD': 2.1608670431318738e-13, 'SHIB-USD': 7.886608257989276e-25, 'AVAX-USD': 0.0}
#
# Forecast Errors:
# {'BTC-USD': h.1    0.000477
# Name: 2023-12-31 00:00:00, dtype: float64, 'ETH-USD': h.1    0.000819
# Name: 2023-12-31 00:00:00, dtype: float64, 'SOL-USD': h.1    0.002774
# Name: 2023-12-31 00:00:00, dtype: float64, 'BNB-USD': h.1    0.001378
# Name: 2023-12-31 00:00:00, dtype: float64, 'XRP-USD': h.1    0.001912
# Name: 2023-12-31 00:00:00, dtype: float64, 'TON-USD': h.1    0.00057
# Name: 2023-12-31 00:00:00, dtype: float64, 'DOGE-USD': h.1    0.000808
# Name: 2023-12-31 00:00:00, dtype: float64, 'ADA-USD': h.1    0.000916
# Name: 2023-12-31 00:00:00, dtype: float64, 'SHIB-USD': h.1    0.002484
# Name: 2023-12-31 00:00:00, dtype: float64, 'AVAX-USD': h.1    0.001257
# Name: 2023-12-31 00:00:00, dtype: float64}
# /Users/ephraim888sun/.pyenv/versions/3.9.6/lib/python3.9/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0008196. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /var/folders/sd/j5p08m515kd7n9549lkkz_q40000gn/T/ipykernel_85199/2994929627.py:29: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast_errors[crypto] = forecast.variance.iloc[-1] - returns[crypto][-1]**2
# /Users/ephraim888sun/.pyenv/versions/3.9.6/lib/python3.9/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.001323. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /var/folders/sd/j5p08m515kd7n9549lkkz_q40000gn/T/ipykernel_85199/2994929627.py:29: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast_errors[crypto] = forecast.variance.iloc[-1] - returns[crypto][-1]**2
# /Users/ephraim888sun/.pyenv/versions/3.9.6/lib/python3.9/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.003262. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /var/folders/sd/j5p08m515kd7n9549lkkz_q40000gn/T/ipykernel_85199/2994929627.py:29: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast_errors[crypto] = forecast.variance.iloc[-1] - returns[crypto][-1]**2
# /Users/ephraim888sun/.pyenv/versions/3.9.6/lib/python3.9/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0009919. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /var/folders/sd/j5p08m515kd7n9549lkkz_q40000gn/T/ipykernel_85199/2994929627.py:29: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast_errors[crypto] = forecast.variance.iloc[-1] - returns[crypto][-1]**2
# /Users/ephraim888sun/.pyenv/versions/3.9.6/lib/python3.9/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002187. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /var/folders/sd/j5p08m515kd7n9549lkkz_q40000gn/T/ipykernel_85199/2994929627.py:29: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast_errors[crypto] = forecast.variance.iloc[-1] - returns[crypto][-1]**2
# /Users/ephraim888sun/.pyenv/versions/3.9.6/lib/python3.9/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.003209. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /var/folders/sd/j5p08m515kd7n9549lkkz_q40000gn/T/ipykernel_85199/2994929627.py:29: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast_errors[crypto] = forecast.variance.iloc[-1] - returns[crypto][-1]**2
# /Users/ephraim888sun/.pyenv/versions/3.9.6/lib/python3.9/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002113. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /var/folders/sd/j5p08m515kd7n9549lkkz_q40000gn/T/ipykernel_85199/2994929627.py:29: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast_errors[crypto] = forecast.variance.iloc[-1] - returns[crypto][-1]**2
# /Users/ephraim888sun/.pyenv/versions/3.9.6/lib/python3.9/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.001767. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /var/folders/sd/j5p08m515kd7n9549lkkz_q40000gn/T/ipykernel_85199/2994929627.py:29: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast_errors[crypto] = forecast.variance.iloc[-1] - returns[crypto][-1]**2
# /Users/ephraim888sun/.pyenv/versions/3.9.6/lib/python3.9/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.003173. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /var/folders/sd/j5p08m515kd7n9549lkkz_q40000gn/T/ipykernel_85199/2994929627.py:29: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast_errors[crypto] = forecast.variance.iloc[-1] - returns[crypto][-1]**2
# /Users/ephraim888sun/.pyenv/versions/3.9.6/lib/python3.9/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002611. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /var/folders/sd/j5p08m515kd7n9549lkkz_q40000gn/T/ipykernel_85199/2994929627.py:29: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast_errors[crypto] = forecast.variance.iloc[-1] - returns[crypto][-1]**2

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Convert dictionaries to DataFrame
aic_df = pd.DataFrame.from_dict(aic_values, orient='index', columns=['AIC'])
bic_df = pd.DataFrame.from_dict(bic_values, orient='index', columns=['BIC'])
std_df = pd.DataFrame.from_dict(residuals_std, orient='index', columns=['Std. Dev. of Residuals'])
adf_df = pd.DataFrame.from_dict(adf_pvalues, orient='index', columns=['ADF p-value'])
forecast_errors_df = pd.DataFrame.from_dict(forecast_errors, orient='index', columns=['Forecast Error'])

# Concatenate DataFrames
comparison_df = pd.concat([aic_df, bic_df, std_df, adf_df, forecast_errors_df], axis=1)

# Display DataFrame
print("Comparison of GARCH Model Analysis:")
print(comparison_df)

# Plot AIC and BIC values
plt.figure(figsize=(10, 6))
plt.plot(aic_df, label='AIC')
plt.plot(bic_df, label='BIC')
plt.title('Comparison of AIC and BIC Values')
plt.xlabel('Cryptocurrency')
plt.ylabel('Value')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# Plot Standard Deviation of Residuals
plt.figure(figsize=(10, 6))
plt.bar(std_df.index, std_df['Std. Dev. of Residuals'])
plt.title('Standard Deviation of Residuals for Cryptocurrencies')
plt.xlabel('Cryptocurrency')
plt.ylabel('Standard Deviation')
plt.xticks(rotation=45)
plt.show()

# Plot Augmented Dickey-Fuller Test p-values
plt.figure(figsize=(10, 6))
plt.bar(adf_df.index, adf_df['ADF p-value'])
plt.title('Augmented Dickey-Fuller Test p-values for Cryptocurrencies')
plt.xlabel('Cryptocurrency')
plt.ylabel('ADF p-value')
plt.xticks(rotation=45)
plt.show()

# Plot Forecast Errors
plt.figure(figsize=(10, 6))
plt.bar(forecast_errors_df.index, forecast_errors_df['Forecast Error'])
plt.title('Forecast Errors for Cryptocurrencies')
plt.xlabel('Cryptocurrency')
plt.ylabel('Forecast Error')
plt.xticks(rotation=45)
plt.show()
# Out:
# Comparison of GARCH Model Analysis:
#                   AIC          BIC  Std. Dev. of Residuals   ADF p-value  \
# BTC-USD  -3168.474379 -3150.107684                0.028649  0.000000e+00
# ETH-USD  -2880.578760 -2862.212065                0.036397  1.087441e-14
# SOL-USD  -2210.558319 -2192.191624                0.057153  5.119591e-13
# BNB-USD  -3089.123719 -3070.757024                0.031515  0.000000e+00
# XRP-USD  -2402.875705 -2384.509010                0.046798  0.000000e+00
# TON-USD  -2406.255007 -2387.888312                0.056683  5.528002e-17
# DOGE-USD -2609.132921 -2590.766226                0.046002  2.384272e-11
# ADA-USD  -2634.344787 -2615.978092                0.042070  2.160867e-13
# SHIB-USD -2164.404234 -2146.037539                0.056366  7.886608e-25
# AVAX-USD -2389.511254 -2371.144559                0.051132  0.000000e+00
#
#          Forecast Error
# BTC-USD             NaN
# ETH-USD             NaN
# SOL-USD             NaN
# BNB-USD             NaN
# XRP-USD             NaN
# TON-USD             NaN
# DOGE-USD            NaN
# ADA-USD             NaN
# SHIB-USD            NaN
# AVAX-USD            NaN

# %% [markdown]
# When AIC (Akaike Information Criterion) and BIC (Bayesian Information Criterion) values are very close to each other and negative, it indicates that the GARCH model provides a good fit to the data. Both AIC and BIC are information criteria used for model selection, with lower values indicating a better fit.
#
# Here's what it means:
#
# Close Values: When AIC and BIC values are close to each other, it suggests that the model is not penalized much for complexity by using the BIC compared to the AIC. This is often observed when the sample size is large relative to the number of parameters estimated by the model.
#
# Negative Values: Both AIC and BIC can take negative values. Negative values are not inherently problematic and simply indicate the relative goodness of fit of the model. Lower (more negative) values indicate a better fit relative to other models being compared.
#
# Interpretation: In your case, an AIC value of -1457.985088 suggests that the GARCH model provides a very good fit to the data for the given cryptocurrency. The closeness of AIC and BIC values indicates that the model's complexity is adequately balanced with the goodness of fit, suggesting that it may be a suitable model for volatility forecasting for that particular cryptocurrency. However, it's essential to compare these values across different models and cryptocurrencies to make informed decisions about model selection.
