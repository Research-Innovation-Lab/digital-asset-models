# %% [markdown]
# # GARCH (Generalized Autoregressive Conditional Heteroskedasticity)

# %% [markdown]
# The GARCH model is an econometric model that captures the time-varying volatility or variance of a time series. It assumes that the volatility of the series is autocorrelated and can be predicted based on past values of the series and past volatility.
#
# The basic form of the GARCH(p, q) model is:
#
# ```
# 𝜎_{𝑡}^2 = 𝜔 + 𝛼_{1}⋅𝜀_{𝑡−1}^2 + … + 𝛼_{𝑝}⋅𝜀_{𝑡−𝑝}^2 + 𝛽_{1}⋅𝜎_{𝑡−1}^2 + … + 𝛽_{𝑞}⋅𝜎_{𝑡−𝑞}^2
# ```
#
# Where:
#
# - \( 𝜎_{𝑡}^2 \) is the conditional variance at time \( 𝑡 \),
# - \( 𝜔 \) is the constant term,
# - \( 𝜀_{𝑡} \) is the error term at time \( 𝑡 \),
# - \( 𝛼_{𝑖} \) and \( 𝛽_{𝑖} \) are the coefficients for the squared error terms and the conditional variances at lag \( 𝑖 \) respectively,
# - \( 𝑝 \) and \( 𝑞 \) are the orders of the autoregressive and moving average terms respectively.

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import arch
import matplotlib.pyplot as plt
from arch.unitroot import ADF

# %%
# Define the cryptocurrencies
cryptos = ['BTC-USD', 'ETH-USD', 'SOL-USD', 'BNB-USD', 'XRP-USD', 'TON-USD', 'DOGE-USD', 'ADA-USD', 'SHIB-USD', 'AVAX-USD']

# Download data for the cryptocurrencies
data = yf.download(cryptos, start="2022-01-01", end="2023-01-01")
# Out:
# [*********************100%%**********************]  10 of 10 completed

# %%
# Close prices
prices = data['Adj Close']

# Calculate daily returns
returns = prices.pct_change().dropna()

# %%
# Fit GARCH model for each cryptocurrency
for crypto in cryptos:
    # Create GARCH model
    model = arch.arch_model(returns[crypto], vol='Garch', p=1, q=1)
    
    # Fit model
    results = model.fit()
    
    # Print summary
    print(f"\nSummary for {crypto}:")
    print(results.summary())
    
    # Plot volatility
    results.plot()
# Out:
# /Users/ephraim888sun/.pyenv/versions/3.9.6/lib/python3.9/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.001103. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/ephraim888sun/.pyenv/versions/3.9.6/lib/python3.9/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002043. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/ephraim888sun/.pyenv/versions/3.9.6/lib/python3.9/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.003752. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/ephraim888sun/.pyenv/versions/3.9.6/lib/python3.9/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.001437. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/ephraim888sun/.pyenv/versions/3.9.6/lib/python3.9/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.001985. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/ephraim888sun/.pyenv/versions/3.9.6/lib/python3.9/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002003. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 16877537.345237114
# Iteration:      2,   Func. Count:     17,   Neg. LLF: -436.85404816792834
# Iteration:      3,   Func. Count:     25,   Neg. LLF: -684.3539471882598
# Iteration:      4,   Func. Count:     31,   Neg. LLF: -721.8326412428622
# Iteration:      5,   Func. Count:     37,   Neg. LLF: -579.7663664715337
# Iteration:      6,   Func. Count:     43,   Neg. LLF: -732.9916780848533
# Iteration:      7,   Func. Count:     48,   Neg. LLF: -732.9925151026498
# Iteration:      8,   Func. Count:     53,   Neg. LLF: -732.9925426826896
# Iteration:      9,   Func. Count:     58,   Neg. LLF: -732.9925438776487
# Iteration:     10,   Func. Count:     62,   Neg. LLF: -732.9925438776547
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -732.9925438776487
#             Iterations: 10
#             Function evaluations: 62
#             Gradient evaluations: 10
#
# Summary for BTC-USD:
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                BTC-USD   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:                732.993
# Distribution:                  Normal   AIC:                          -1457.99
# Method:            Maximum Likelihood   BIC:                          -1442.40
#                                         No. Observations:                  364
# Date:                Thu, May 16 2024   Df Residuals:                      363
# Time:                        18:34:30   Df Model:                            1
#                                   Mean Model
# ==============================================================================
#                   coef    std err          t      P>|t|       95.0% Conf. Int.
# ------------------------------------------------------------------------------
# mu         -2.6978e-04  1.872e-03     -0.144      0.885 [-3.940e-03,3.400e-03]
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega      4.5444e-04  2.201e-04      2.065  3.895e-02 [2.306e-05,8.858e-04]
# alpha[1]       0.2680      0.253      1.059      0.290     [ -0.228,  0.764]
# beta[1]        0.3613      0.265      1.364      0.173     [ -0.158,  0.881]
# ============================================================================
#
# Covariance estimator: robust
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 15666530.683329582
# Iteration:      2,   Func. Count:     17,   Neg. LLF: 520.2996096575897
# Iteration:      3,   Func. Count:     25,   Neg. LLF: 2202369.2903918754
# Iteration:      4,   Func. Count:     31,   Neg. LLF: -617.3422178457577
# Iteration:      5,   Func. Count:     38,   Neg. LLF: -622.9085971768427
# Iteration:      6,   Func. Count:     44,   Neg. LLF: -623.4211966489144
# Iteration:      7,   Func. Count:     49,   Neg. LLF: -623.421602875383
# Iteration:      8,   Func. Count:     54,   Neg. LLF: -623.4216045246853
# Iteration:      9,   Func. Count:     58,   Neg. LLF: -623.4216045247515
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -623.4216045246853
#             Iterations: 9
#             Function evaluations: 58
#             Gradient evaluations: 9
#
# Summary for ETH-USD:
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                ETH-USD   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:                623.422
# Distribution:                  Normal   AIC:                          -1238.84
# Method:            Maximum Likelihood   BIC:                          -1223.25
#                                         No. Observations:                  364
# Date:                Thu, May 16 2024   Df Residuals:                      363
# Time:                        18:34:30   Df Model:                            1
#                                   Mean Model
# ==============================================================================
#                   coef    std err          t      P>|t|       95.0% Conf. Int.
# ------------------------------------------------------------------------------
# mu         -5.7406e-04  2.201e-03     -0.261      0.794 [-4.889e-03,3.740e-03]
#                                Volatility Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# omega      5.0886e-04  3.222e-04      1.579      0.114 [-1.227e-04,1.140e-03]
# alpha[1]       0.1745  8.654e-02      2.016  4.381e-02    [4.841e-03,  0.344]
# beta[1]        0.5814      0.195      2.984  2.849e-03      [  0.199,  0.963]
# =============================================================================
#
# Covariance estimator: robust
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 7076727594180658.0
# Iteration:      2,   Func. Count:     16,   Neg. LLF: 162.0015792480964
# Iteration:      3,   Func. Count:     22,   Neg. LLF: -478.1041547681143
# Iteration:      4,   Func. Count:     28,   Neg. LLF: -531.8531112064729
# Iteration:      5,   Func. Count:     34,   Neg. LLF: -515.1474742300657
# Iteration:      6,   Func. Count:     40,   Neg. LLF: -428.61973103511565
# Iteration:      7,   Func. Count:     47,   Neg. LLF: -528.7440492498199
# Iteration:      8,   Func. Count:     54,   Neg. LLF: -536.842156550529
# Iteration:      9,   Func. Count:     59,   Neg. LLF: -536.8442330125405
# Iteration:     10,   Func. Count:     64,   Neg. LLF: -536.8442564817102
# Iteration:     11,   Func. Count:     68,   Neg. LLF: -536.8442564816382
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -536.8442564817102
#             Iterations: 11
#             Function evaluations: 68
#             Gradient evaluations: 11
#
# Summary for SOL-USD:
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                SOL-USD   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:                536.844
# Distribution:                  Normal   AIC:                          -1065.69
# Method:            Maximum Likelihood   BIC:                          -1050.10
#                                         No. Observations:                  364
# Date:                Thu, May 16 2024   Df Residuals:                      363
# Time:                        18:34:30   Df Model:                            1
#                                   Mean Model
# ==============================================================================
#                   coef    std err          t      P>|t|       95.0% Conf. Int.
# ------------------------------------------------------------------------------
# mu         -2.9514e-03  2.702e-03     -1.092      0.275 [-8.248e-03,2.345e-03]
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega      1.1925e-03  4.204e-04      2.837  4.558e-03 [3.686e-04,2.016e-03]
# alpha[1]       0.3145      0.128      2.462  1.381e-02   [6.416e-02,  0.565]
# beta[1]        0.3517      0.167      2.104  3.537e-02   [2.408e-02,  0.679]
# ============================================================================
#
# Covariance estimator: robust
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 59773872.08736051
# Iteration:      2,   Func. Count:     17,   Neg. LLF: 1348.1696936113685
# Iteration:      3,   Func. Count:     23,   Neg. LLF: -679.2276918609402
# Iteration:      4,   Func. Count:     30,   Neg. LLF: -539.1665808271498
# Iteration:      5,   Func. Count:     36,   Neg. LLF: -690.1402014285435
# Iteration:      6,   Func. Count:     42,   Neg. LLF: 164437528.60610157
# Iteration:      7,   Func. Count:     48,   Neg. LLF: -685.1569448403683
# Iteration:      8,   Func. Count:     55,   Neg. LLF: -691.9913584794723
# Iteration:      9,   Func. Count:     61,   Neg. LLF: -692.0235507341225
# Iteration:     10,   Func. Count:     67,   Neg. LLF: -692.0250961005538
# Iteration:     11,   Func. Count:     72,   Neg. LLF: -692.0251082314178
# Iteration:     12,   Func. Count:     76,   Neg. LLF: -692.0251082314317
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -692.0251082314178
#             Iterations: 12
#             Function evaluations: 76
#             Gradient evaluations: 12
#
# Summary for BNB-USD:
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                BNB-USD   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:                692.025
# Distribution:                  Normal   AIC:                          -1376.05
# Method:            Maximum Likelihood   BIC:                          -1360.46
#                                         No. Observations:                  364
# Date:                Thu, May 16 2024   Df Residuals:                      363
# Time:                        18:34:30   Df Model:                            1
#                                   Mean Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# mu         7.4170e-04  1.863e-03      0.398      0.691 [-2.910e-03,4.393e-03]
#                                Volatility Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# omega      2.7859e-04  2.759e-04      1.010      0.313 [-2.622e-04,8.194e-04]
# alpha[1]       0.2820      0.153      1.847  6.473e-02   [-1.723e-02,  0.581]
# beta[1]        0.5618      0.248      2.264  2.354e-02    [7.554e-02,  1.048]
# =============================================================================
#
# Covariance estimator: robust
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 187070.55157221085
# Iteration:      2,   Func. Count:     16,   Neg. LLF: 509.15554198261
# Iteration:      3,   Func. Count:     25,   Neg. LLF: -596.450597647352
# Iteration:      4,   Func. Count:     32,   Neg. LLF: -591.9544558258065
# Iteration:      5,   Func. Count:     39,   Neg. LLF: -636.6778967229329
# Iteration:      6,   Func. Count:     46,   Neg. LLF: -643.3819123413593
# Iteration:      7,   Func. Count:     51,   Neg. LLF: -643.3819849619869
# Iteration:      8,   Func. Count:     56,   Neg. LLF: -643.3819875748492
# Iteration:      9,   Func. Count:     60,   Neg. LLF: -643.3819875747465
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -643.3819875748492
#             Iterations: 9
#             Function evaluations: 60
#             Gradient evaluations: 9
#
# Summary for XRP-USD:
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                XRP-USD   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:                643.382
# Distribution:                  Normal   AIC:                          -1278.76
# Method:            Maximum Likelihood   BIC:                          -1263.18
#                                         No. Observations:                  364
# Date:                Thu, May 16 2024   Df Residuals:                      363
# Time:                        18:34:30   Df Model:                            1
#                                   Mean Model
# ==============================================================================
#                   coef    std err          t      P>|t|       95.0% Conf. Int.
# ------------------------------------------------------------------------------
# mu         -1.6413e-03  1.755e-03     -0.935      0.350 [-5.081e-03,1.798e-03]
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega      2.7492e-04  8.824e-05      3.116  1.836e-03 [1.020e-04,4.479e-04]
# alpha[1]       0.2136  7.412e-02      2.882  3.946e-03   [6.837e-02,  0.359]
# beta[1]        0.6614  4.696e-02     14.085  4.697e-45     [  0.569,  0.753]
# ============================================================================
#
# Covariance estimator: robust
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 89055137.34427677
# Iteration:      2,   Func. Count:     17,   Neg. LLF: 307473.2213106623
# Iteration:      3,   Func. Count:     23,   Neg. LLF: -624.5955552657
# Iteration:      4,   Func. Count:     30,   Neg. LLF: -612.1394044469744
# Iteration:      5,   Func. Count:     36,   Neg. LLF: -637.1152717434425
# Iteration:      6,   Func. Count:     42,   Neg. LLF: -638.2195593138462
# Iteration:      7,   Func. Count:     48,   Neg. LLF: -636.3968612526605
# Iteration:      8,   Func. Count:     54,   Neg. LLF: -642.457135722937
# Iteration:      9,   Func. Count:     59,   Neg. LLF: -642.4572674343341
# Iteration:     10,   Func. Count:     64,   Neg. LLF: -642.4573665206631
# Iteration:     11,   Func. Count:     68,   Neg. LLF: -642.4573665205096
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -642.4573665206631
#             Iterations: 11
#             Function evaluations: 68
#             Gradient evaluations: 11
#
# Summary for TON-USD:
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                TON-USD   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:                642.457
# Distribution:                  Normal   AIC:                          -1276.91
# Method:            Maximum Likelihood   BIC:                          -1261.33
#                                         No. Observations:                  364
# Date:                Thu, May 16 2024   Df Residuals:                      363
# Time:                        18:34:30   Df Model:                            1
#                                   Mean Model
# ==============================================================================
#                   coef    std err          t      P>|t|       95.0% Conf. Int.
# ------------------------------------------------------------------------------
# mu         -5.3513e-04  2.291e-03     -0.234      0.815 [-5.026e-03,3.956e-03]
#                                Volatility Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# omega      8.4075e-04  5.903e-04      1.424      0.154 [-3.161e-04,1.998e-03]
# alpha[1]       0.3071      0.145      2.122  3.382e-02    [2.348e-02,  0.591]
# beta[1]        0.2757      0.329      0.838      0.402      [ -0.369,  0.920]
# =============================================================================
#
# Covariance estimator: robust
# /Users/ephraim888sun/.pyenv/versions/3.9.6/lib/python3.9/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.003166. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/ephraim888sun/.pyenv/versions/3.9.6/lib/python3.9/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002275. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/ephraim888sun/.pyenv/versions/3.9.6/lib/python3.9/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.003788. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/ephraim888sun/.pyenv/versions/3.9.6/lib/python3.9/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.003251. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 315616.4404480326
# Iteration:      2,   Func. Count:     16,   Neg. LLF: -207.1784775151082
# Iteration:      3,   Func. Count:     26,   Neg. LLF: -490.7132251024003
# Iteration:      4,   Func. Count:     33,   Neg. LLF: -550.3687546937571
# Iteration:      5,   Func. Count:     39,   Neg. LLF: -547.8347948019007
# Iteration:      6,   Func. Count:     46,   Neg. LLF: -574.1206377396074
# Iteration:      7,   Func. Count:     51,   Neg. LLF: -574.2812887437146
# Iteration:      8,   Func. Count:     56,   Neg. LLF: -574.3187905947609
# Iteration:      9,   Func. Count:     61,   Neg. LLF: -574.3243423343009
# Iteration:     10,   Func. Count:     66,   Neg. LLF: -574.3248122402688
# Iteration:     11,   Func. Count:     71,   Neg. LLF: -574.3248182692118
# Iteration:     12,   Func. Count:     75,   Neg. LLF: -574.3248182692805
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -574.3248182692118
#             Iterations: 12
#             Function evaluations: 75
#             Gradient evaluations: 12
#
# Summary for DOGE-USD:
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:               DOGE-USD   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:                574.325
# Distribution:                  Normal   AIC:                          -1140.65
# Method:            Maximum Likelihood   BIC:                          -1125.06
#                                         No. Observations:                  364
# Date:                Thu, May 16 2024   Df Residuals:                      363
# Time:                        18:34:30   Df Model:                            1
#                                   Mean Model
# ==============================================================================
#                   coef    std err          t      P>|t|       95.0% Conf. Int.
# ------------------------------------------------------------------------------
# mu         -2.2001e-03  2.316e-03     -0.950      0.342 [-6.740e-03,2.340e-03]
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega      8.0954e-04  2.464e-04      3.285  1.019e-03 [3.266e-04,1.292e-03]
# alpha[1]       0.4205      0.191      2.196  2.810e-02   [4.517e-02,  0.796]
# beta[1]        0.3808  9.905e-02      3.845  1.206e-04     [  0.187,  0.575]
# ============================================================================
#
# Covariance estimator: robust
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 7816220.187887609
# Iteration:      2,   Func. Count:     17,   Neg. LLF: 348.71238091321123
# Iteration:      3,   Func. Count:     25,   Neg. LLF: -578.6145605447325
# Iteration:      4,   Func. Count:     32,   Neg. LLF: -571.0036454966653
# Iteration:      5,   Func. Count:     39,   Neg. LLF: -608.8353792514924
# Iteration:      6,   Func. Count:     46,   Neg. LLF: -613.2404652391211
# Iteration:      7,   Func. Count:     51,   Neg. LLF: -613.240478865652
# Iteration:      8,   Func. Count:     55,   Neg. LLF: -613.2404788654649
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -613.240478865652
#             Iterations: 8
#             Function evaluations: 55
#             Gradient evaluations: 8
#
# Summary for ADA-USD:
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                ADA-USD   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:                613.240
# Distribution:                  Normal   AIC:                          -1218.48
# Method:            Maximum Likelihood   BIC:                          -1202.89
#                                         No. Observations:                  364
# Date:                Thu, May 16 2024   Df Residuals:                      363
# Time:                        18:34:30   Df Model:                            1
#                                   Mean Model
# ==============================================================================
#                   coef    std err          t      P>|t|       95.0% Conf. Int.
# ------------------------------------------------------------------------------
# mu         -2.7335e-03  2.040e-03     -1.340      0.180 [-6.731e-03,1.264e-03]
#                                Volatility Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# omega      3.0166e-04  1.586e-04      1.902  5.720e-02 [-9.230e-06,6.126e-04]
# alpha[1]       0.1987  7.132e-02      2.786  5.340e-03    [5.889e-02,  0.338]
# beta[1]        0.6787  9.145e-02      7.422  1.153e-13      [  0.499,  0.858]
# =============================================================================
#
# Covariance estimator: robust
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 176241.46458357555
# Iteration:      2,   Func. Count:     16,   Neg. LLF: 632.4620143023755
# Iteration:      3,   Func. Count:     24,   Neg. LLF: -478.76589228874764
# Iteration:      4,   Func. Count:     31,   Neg. LLF: -486.31610348323443
# Iteration:      5,   Func. Count:     37,   Neg. LLF: -511.02253551953146
# Iteration:      6,   Func. Count:     43,   Neg. LLF: -511.2139458260232
# Iteration:      7,   Func. Count:     48,   Neg. LLF: -511.2139559116391
# Iteration:      8,   Func. Count:     52,   Neg. LLF: -511.2139559115964
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -511.2139559116391
#             Iterations: 8
#             Function evaluations: 52
#             Gradient evaluations: 8
#
# Summary for SHIB-USD:
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:               SHIB-USD   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:                511.214
# Distribution:                  Normal   AIC:                          -1014.43
# Method:            Maximum Likelihood   BIC:                          -998.839
#                                         No. Observations:                  364
# Date:                Thu, May 16 2024   Df Residuals:                      363
# Time:                        18:34:30   Df Model:                            1
#                                   Mean Model
# ==============================================================================
#                   coef    std err          t      P>|t|       95.0% Conf. Int.
# ------------------------------------------------------------------------------
# mu         -1.7371e-03  2.716e-03     -0.640      0.522 [-7.060e-03,3.586e-03]
#                                Volatility Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# omega      1.7414e-03  9.026e-04      1.929  5.368e-02 [-2.760e-05,3.510e-03]
# alpha[1]       0.1994      0.126      1.588      0.112   [-4.673e-02,  0.445]
# beta[1]        0.3550      0.240      1.479      0.139      [ -0.115,  0.825]
# =============================================================================
#
# Covariance estimator: robust
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 15821089.919407114
# Iteration:      2,   Func. Count:     17,   Neg. LLF: 65235.8961162344
# Iteration:      3,   Func. Count:     24,   Neg. LLF: -548.3721258819704
# Iteration:      4,   Func. Count:     30,   Neg. LLF: -552.9759878219675
# Iteration:      5,   Func. Count:     37,   Neg. LLF: 5513.624169549428
# Iteration:      6,   Func. Count:     47,   Neg. LLF: 619.9291869472946
# Iteration:      7,   Func. Count:     56,   Neg. LLF: -548.1990040415055
# Iteration:      8,   Func. Count:     62,   Neg. LLF: -553.9684627176749
# Iteration:      9,   Func. Count:     67,   Neg. LLF: -548.0918674049991
# Iteration:     10,   Func. Count:     73,   Neg. LLF: -544.1579904276603
# Iteration:     11,   Func. Count:     81,   Neg. LLF: -552.407134096297
# Iteration:     12,   Func. Count:     87,   Neg. LLF: -554.3513459125845
# Iteration:     13,   Func. Count:     92,   Neg. LLF: -554.3528144263087
# Iteration:     14,   Func. Count:     97,   Neg. LLF: -554.3528330613309
# Iteration:     15,   Func. Count:    101,   Neg. LLF: -554.3528330611796
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -554.3528330613309
#             Iterations: 16
#             Function evaluations: 101
#             Gradient evaluations: 15
#
# Summary for AVAX-USD:
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:               AVAX-USD   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:                554.353
# Distribution:                  Normal   AIC:                          -1100.71
# Method:            Maximum Likelihood   BIC:                          -1085.12
#                                         No. Observations:                  364
# Date:                Thu, May 16 2024   Df Residuals:                      363
# Time:                        18:34:30   Df Model:                            1
#                                   Mean Model
# ==============================================================================
#                   coef    std err          t      P>|t|       95.0% Conf. Int.
# ------------------------------------------------------------------------------
# mu         -3.0075e-03  2.294e-03     -1.311      0.190 [-7.504e-03,1.489e-03]
#                                Volatility Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# omega      1.3601e-04  8.250e-05      1.649  9.922e-02 [-2.569e-05,2.977e-04]
# alpha[1]       0.2114  7.402e-02      2.856  4.288e-03    [6.634e-02,  0.356]
# beta[1]        0.7649  6.200e-02     12.336  5.762e-35      [  0.643,  0.886]
# =============================================================================
#
# Covariance estimator: robust

# %%
# Initialize a plot
plt.figure(figsize=(12, 8))

# Iterate over each cryptocurrency
for crypto in cryptos:
    # Create GARCH model
    model = arch.arch_model(returns[crypto], vol='Garch', p=1, q=1)
    
    # Fit model
    results = model.fit()
    
    # Plot volatility forecast
    plt.plot(results.conditional_volatility, label=crypto)

# Add labels and legend
plt.title('GARCH Volatility Forecast Comparison')
plt.xlabel('Date')
plt.ylabel('Volatility')
plt.legend()

# Show plot
plt.show()
# Out:
# /Users/ephraim888sun/.pyenv/versions/3.9.6/lib/python3.9/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.001103. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/ephraim888sun/.pyenv/versions/3.9.6/lib/python3.9/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002043. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/ephraim888sun/.pyenv/versions/3.9.6/lib/python3.9/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.003752. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/ephraim888sun/.pyenv/versions/3.9.6/lib/python3.9/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.001437. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/ephraim888sun/.pyenv/versions/3.9.6/lib/python3.9/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.001985. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/ephraim888sun/.pyenv/versions/3.9.6/lib/python3.9/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002003. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/ephraim888sun/.pyenv/versions/3.9.6/lib/python3.9/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.003166. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/ephraim888sun/.pyenv/versions/3.9.6/lib/python3.9/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002275. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/ephraim888sun/.pyenv/versions/3.9.6/lib/python3.9/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.003788. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/ephraim888sun/.pyenv/versions/3.9.6/lib/python3.9/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.003251. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 16877537.345237114
# Iteration:      2,   Func. Count:     17,   Neg. LLF: -436.85404816792834
# Iteration:      3,   Func. Count:     25,   Neg. LLF: -684.3539471882598
# Iteration:      4,   Func. Count:     31,   Neg. LLF: -721.8326412428622
# Iteration:      5,   Func. Count:     37,   Neg. LLF: -579.7663664715337
# Iteration:      6,   Func. Count:     43,   Neg. LLF: -732.9916780848533
# Iteration:      7,   Func. Count:     48,   Neg. LLF: -732.9925151026498
# Iteration:      8,   Func. Count:     53,   Neg. LLF: -732.9925426826896
# Iteration:      9,   Func. Count:     58,   Neg. LLF: -732.9925438776487
# Iteration:     10,   Func. Count:     62,   Neg. LLF: -732.9925438776547
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -732.9925438776487
#             Iterations: 10
#             Function evaluations: 62
#             Gradient evaluations: 10
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 15666530.683329582
# Iteration:      2,   Func. Count:     17,   Neg. LLF: 520.2996096575897
# Iteration:      3,   Func. Count:     25,   Neg. LLF: 2202369.2903918754
# Iteration:      4,   Func. Count:     31,   Neg. LLF: -617.3422178457577
# Iteration:      5,   Func. Count:     38,   Neg. LLF: -622.9085971768427
# Iteration:      6,   Func. Count:     44,   Neg. LLF: -623.4211966489144
# Iteration:      7,   Func. Count:     49,   Neg. LLF: -623.421602875383
# Iteration:      8,   Func. Count:     54,   Neg. LLF: -623.4216045246853
# Iteration:      9,   Func. Count:     58,   Neg. LLF: -623.4216045247515
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -623.4216045246853
#             Iterations: 9
#             Function evaluations: 58
#             Gradient evaluations: 9
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 7076727594180658.0
# Iteration:      2,   Func. Count:     16,   Neg. LLF: 162.0015792480964
# Iteration:      3,   Func. Count:     22,   Neg. LLF: -478.1041547681143
# Iteration:      4,   Func. Count:     28,   Neg. LLF: -531.8531112064729
# Iteration:      5,   Func. Count:     34,   Neg. LLF: -515.1474742300657
# Iteration:      6,   Func. Count:     40,   Neg. LLF: -428.61973103511565
# Iteration:      7,   Func. Count:     47,   Neg. LLF: -528.7440492498199
# Iteration:      8,   Func. Count:     54,   Neg. LLF: -536.842156550529
# Iteration:      9,   Func. Count:     59,   Neg. LLF: -536.8442330125405
# Iteration:     10,   Func. Count:     64,   Neg. LLF: -536.8442564817102
# Iteration:     11,   Func. Count:     68,   Neg. LLF: -536.8442564816382
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -536.8442564817102
#             Iterations: 11
#             Function evaluations: 68
#             Gradient evaluations: 11
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 59773872.08736051
# Iteration:      2,   Func. Count:     17,   Neg. LLF: 1348.1696936113685
# Iteration:      3,   Func. Count:     23,   Neg. LLF: -679.2276918609402
# Iteration:      4,   Func. Count:     30,   Neg. LLF: -539.1665808271498
# Iteration:      5,   Func. Count:     36,   Neg. LLF: -690.1402014285435
# Iteration:      6,   Func. Count:     42,   Neg. LLF: 164437528.60610157
# Iteration:      7,   Func. Count:     48,   Neg. LLF: -685.1569448403683
# Iteration:      8,   Func. Count:     55,   Neg. LLF: -691.9913584794723
# Iteration:      9,   Func. Count:     61,   Neg. LLF: -692.0235507341225
# Iteration:     10,   Func. Count:     67,   Neg. LLF: -692.0250961005538
# Iteration:     11,   Func. Count:     72,   Neg. LLF: -692.0251082314178
# Iteration:     12,   Func. Count:     76,   Neg. LLF: -692.0251082314317
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -692.0251082314178
#             Iterations: 12
#             Function evaluations: 76
#             Gradient evaluations: 12
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 187070.55157221085
# Iteration:      2,   Func. Count:     16,   Neg. LLF: 509.15554198261
# Iteration:      3,   Func. Count:     25,   Neg. LLF: -596.450597647352
# Iteration:      4,   Func. Count:     32,   Neg. LLF: -591.9544558258065
# Iteration:      5,   Func. Count:     39,   Neg. LLF: -636.6778967229329
# Iteration:      6,   Func. Count:     46,   Neg. LLF: -643.3819123413593
# Iteration:      7,   Func. Count:     51,   Neg. LLF: -643.3819849619869
# Iteration:      8,   Func. Count:     56,   Neg. LLF: -643.3819875748492
# Iteration:      9,   Func. Count:     60,   Neg. LLF: -643.3819875747465
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -643.3819875748492
#             Iterations: 9
#             Function evaluations: 60
#             Gradient evaluations: 9
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 89055137.34427677
# Iteration:      2,   Func. Count:     17,   Neg. LLF: 307473.2213106623
# Iteration:      3,   Func. Count:     23,   Neg. LLF: -624.5955552657
# Iteration:      4,   Func. Count:     30,   Neg. LLF: -612.1394044469744
# Iteration:      5,   Func. Count:     36,   Neg. LLF: -637.1152717434425
# Iteration:      6,   Func. Count:     42,   Neg. LLF: -638.2195593138462
# Iteration:      7,   Func. Count:     48,   Neg. LLF: -636.3968612526605
# Iteration:      8,   Func. Count:     54,   Neg. LLF: -642.457135722937
# Iteration:      9,   Func. Count:     59,   Neg. LLF: -642.4572674343341
# Iteration:     10,   Func. Count:     64,   Neg. LLF: -642.4573665206631
# Iteration:     11,   Func. Count:     68,   Neg. LLF: -642.4573665205096
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -642.4573665206631
#             Iterations: 11
#             Function evaluations: 68
#             Gradient evaluations: 11
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 315616.4404480326
# Iteration:      2,   Func. Count:     16,   Neg. LLF: -207.1784775151082
# Iteration:      3,   Func. Count:     26,   Neg. LLF: -490.7132251024003
# Iteration:      4,   Func. Count:     33,   Neg. LLF: -550.3687546937571
# Iteration:      5,   Func. Count:     39,   Neg. LLF: -547.8347948019007
# Iteration:      6,   Func. Count:     46,   Neg. LLF: -574.1206377396074
# Iteration:      7,   Func. Count:     51,   Neg. LLF: -574.2812887437146
# Iteration:      8,   Func. Count:     56,   Neg. LLF: -574.3187905947609
# Iteration:      9,   Func. Count:     61,   Neg. LLF: -574.3243423343009
# Iteration:     10,   Func. Count:     66,   Neg. LLF: -574.3248122402688
# Iteration:     11,   Func. Count:     71,   Neg. LLF: -574.3248182692118
# Iteration:     12,   Func. Count:     75,   Neg. LLF: -574.3248182692805
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -574.3248182692118
#             Iterations: 12
#             Function evaluations: 75
#             Gradient evaluations: 12
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 7816220.187887609
# Iteration:      2,   Func. Count:     17,   Neg. LLF: 348.71238091321123
# Iteration:      3,   Func. Count:     25,   Neg. LLF: -578.6145605447325
# Iteration:      4,   Func. Count:     32,   Neg. LLF: -571.0036454966653
# Iteration:      5,   Func. Count:     39,   Neg. LLF: -608.8353792514924
# Iteration:      6,   Func. Count:     46,   Neg. LLF: -613.2404652391211
# Iteration:      7,   Func. Count:     51,   Neg. LLF: -613.240478865652
# Iteration:      8,   Func. Count:     55,   Neg. LLF: -613.2404788654649
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -613.240478865652
#             Iterations: 8
#             Function evaluations: 55
#             Gradient evaluations: 8
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 176241.46458357555
# Iteration:      2,   Func. Count:     16,   Neg. LLF: 632.4620143023755
# Iteration:      3,   Func. Count:     24,   Neg. LLF: -478.76589228874764
# Iteration:      4,   Func. Count:     31,   Neg. LLF: -486.31610348323443
# Iteration:      5,   Func. Count:     37,   Neg. LLF: -511.02253551953146
# Iteration:      6,   Func. Count:     43,   Neg. LLF: -511.2139458260232
# Iteration:      7,   Func. Count:     48,   Neg. LLF: -511.2139559116391
# Iteration:      8,   Func. Count:     52,   Neg. LLF: -511.2139559115964
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -511.2139559116391
#             Iterations: 8
#             Function evaluations: 52
#             Gradient evaluations: 8
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 15821089.919407114
# Iteration:      2,   Func. Count:     17,   Neg. LLF: 65235.8961162344
# Iteration:      3,   Func. Count:     24,   Neg. LLF: -548.3721258819704
# Iteration:      4,   Func. Count:     30,   Neg. LLF: -552.9759878219675
# Iteration:      5,   Func. Count:     37,   Neg. LLF: 5513.624169549428
# Iteration:      6,   Func. Count:     47,   Neg. LLF: 619.9291869472946
# Iteration:      7,   Func. Count:     56,   Neg. LLF: -548.1990040415055
# Iteration:      8,   Func. Count:     62,   Neg. LLF: -553.9684627176749
# Iteration:      9,   Func. Count:     67,   Neg. LLF: -548.0918674049991
# Iteration:     10,   Func. Count:     73,   Neg. LLF: -544.1579904276603
# Iteration:     11,   Func. Count:     81,   Neg. LLF: -552.407134096297
# Iteration:     12,   Func. Count:     87,   Neg. LLF: -554.3513459125845
# Iteration:     13,   Func. Count:     92,   Neg. LLF: -554.3528144263087
# Iteration:     14,   Func. Count:     97,   Neg. LLF: -554.3528330613309
# Iteration:     15,   Func. Count:    101,   Neg. LLF: -554.3528330611796
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -554.3528330613309
#             Iterations: 16
#             Function evaluations: 101
#             Gradient evaluations: 15

# %% [markdown]
# ## Metrics

# %%
# Fit GARCH model for each cryptocurrency
aic_values = {}
bic_values = {}
residuals_std = {}
adf_pvalues = {}
forecast_errors = {}

for crypto in cryptos:
    # Create GARCH model
    model = arch.arch_model(returns[crypto], vol='Garch', p=1, q=1)
    
    # Fit model
    results = model.fit(disp='off')
    
    # Calculate AIC and BIC
    aic_values[crypto] = results.aic
    bic_values[crypto] = results.bic
    
    # Residual analysis
    residuals = results.resid
    residuals_std[crypto] = residuals.std()
    
    # Augmented Dickey-Fuller test for residual stationarity
    adf_test = ADF(residuals)
    adf_pvalues[crypto] = adf_test.pvalue
    
    # Out-of-sample forecasting
    forecast = results.forecast(horizon=1)
    forecast_errors[crypto] = forecast.variance.iloc[-1] - returns[crypto][-1]**2

# Display results
print("AIC Values:")
print(aic_values)
print("\nBIC Values:")
print(bic_values)
print("\nStandard Deviation of Residuals:")
print(residuals_std)
print("\nAugmented Dickey-Fuller Test p-values:")
print(adf_pvalues)
print("\nForecast Errors:")
print(forecast_errors)
# Out:
# /Users/ephraim888sun/.pyenv/versions/3.9.6/lib/python3.9/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.001103. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /var/folders/sd/j5p08m515kd7n9549lkkz_q40000gn/T/ipykernel_65884/2994929627.py:29: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast_errors[crypto] = forecast.variance.iloc[-1] - returns[crypto][-1]**2
# /Users/ephraim888sun/.pyenv/versions/3.9.6/lib/python3.9/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002043. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /var/folders/sd/j5p08m515kd7n9549lkkz_q40000gn/T/ipykernel_65884/2994929627.py:29: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast_errors[crypto] = forecast.variance.iloc[-1] - returns[crypto][-1]**2
# /Users/ephraim888sun/.pyenv/versions/3.9.6/lib/python3.9/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.003752. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /var/folders/sd/j5p08m515kd7n9549lkkz_q40000gn/T/ipykernel_65884/2994929627.py:29: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast_errors[crypto] = forecast.variance.iloc[-1] - returns[crypto][-1]**2
# /Users/ephraim888sun/.pyenv/versions/3.9.6/lib/python3.9/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.001437. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /var/folders/sd/j5p08m515kd7n9549lkkz_q40000gn/T/ipykernel_65884/2994929627.py:29: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast_errors[crypto] = forecast.variance.iloc[-1] - returns[crypto][-1]**2
# /Users/ephraim888sun/.pyenv/versions/3.9.6/lib/python3.9/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.001985. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /var/folders/sd/j5p08m515kd7n9549lkkz_q40000gn/T/ipykernel_65884/2994929627.py:29: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast_errors[crypto] = forecast.variance.iloc[-1] - returns[crypto][-1]**2
# /Users/ephraim888sun/.pyenv/versions/3.9.6/lib/python3.9/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002003. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /var/folders/sd/j5p08m515kd7n9549lkkz_q40000gn/T/ipykernel_65884/2994929627.py:29: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast_errors[crypto] = forecast.variance.iloc[-1] - returns[crypto][-1]**2
# /Users/ephraim888sun/.pyenv/versions/3.9.6/lib/python3.9/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.003166. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /var/folders/sd/j5p08m515kd7n9549lkkz_q40000gn/T/ipykernel_65884/2994929627.py:29: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast_errors[crypto] = forecast.variance.iloc[-1] - returns[crypto][-1]**2
# /Users/ephraim888sun/.pyenv/versions/3.9.6/lib/python3.9/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.002275. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /var/folders/sd/j5p08m515kd7n9549lkkz_q40000gn/T/ipykernel_65884/2994929627.py:29: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast_errors[crypto] = forecast.variance.iloc[-1] - returns[crypto][-1]**2
# /Users/ephraim888sun/.pyenv/versions/3.9.6/lib/python3.9/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.003788. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# AIC Values:
# {'BTC-USD': -1457.9850877552974, 'ETH-USD': -1238.8432090493707, 'SOL-USD': -1065.6885129634204, 'BNB-USD': -1376.0502164628356, 'XRP-USD': -1278.7639751496984, 'TON-USD': -1276.9147330413261, 'DOGE-USD': -1140.6496365384237, 'ADA-USD': -1218.480957731304, 'SHIB-USD': -1014.4279118232782, 'AVAX-USD': -1100.7056661226618}
#
# BIC Values:
# {'BTC-USD': -1442.3964722847504, 'ETH-USD': -1223.2545935788237, 'SOL-USD': -1050.0998974928734, 'BNB-USD': -1360.4616009922886, 'XRP-USD': -1263.1753596791514, 'TON-USD': -1261.3261175707792, 'DOGE-USD': -1125.0610210678767, 'ADA-USD': -1202.892342260757, 'SHIB-USD': -998.8392963527313, 'AVAX-USD': -1085.1170506521148}
#
# Standard Deviation of Residuals:
# {'BTC-USD': 0.03326189612507, 'ETH-USD': 0.04526232344373637, 'SOL-USD': 0.06133575708956018, 'BNB-USD': 0.0379562914787767, 'XRP-USD': 0.04461584402267554, 'TON-USD': 0.04481316632851174, 'DOGE-USD': 0.05634326832242969, 'ADA-USD': 0.04776619425968532, 'SHIB-USD': 0.061631162793894474, 'AVAX-USD': 0.057094285475330325}
#
# Augmented Dickey-Fuller Test p-values:
# {'BTC-USD': 0.0, 'ETH-USD': 0.0, 'SOL-USD': 0.0, 'BNB-USD': 0.0, 'XRP-USD': 8.920450222665974e-19, 'TON-USD': 2.030323567032998e-30, 'DOGE-USD': 1.6095246045896208e-06, 'ADA-USD': 1.2175074682642171e-08, 'SHIB-USD': 2.0324704203345833e-19, 'AVAX-USD': 0.0}
#
# Forecast Errors:
# {'BTC-USD': h.1    0.000706
# Name: 2022-12-31 00:00:00, dtype: float64, 'ETH-USD': h.1    0.001234
# Name: 2022-12-31 00:00:00, dtype: float64, 'SOL-USD': h.1    0.002081
# Name: 2022-12-31 00:00:00, dtype: float64, 'BNB-USD': h.1    0.000652
# Name: 2022-12-31 00:00:00, dtype: float64, 'XRP-USD': h.1    0.000927
# Name: 2022-12-31 00:00:00, dtype: float64, 'TON-USD': h.1    0.000818
# Name: 2022-12-31 00:00:00, dtype: float64, 'DOGE-USD': h.1    0.001171
# Name: 2022-12-31 00:00:00, dtype: float64, 'ADA-USD': h.1    0.001129
# Name: 2022-12-31 00:00:00, dtype: float64, 'SHIB-USD': h.1    0.002701
# Name: 2022-12-31 00:00:00, dtype: float64, 'AVAX-USD': h.1    0.000847
# Name: 2022-12-31 00:00:00, dtype: float64}
# /var/folders/sd/j5p08m515kd7n9549lkkz_q40000gn/T/ipykernel_65884/2994929627.py:29: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast_errors[crypto] = forecast.variance.iloc[-1] - returns[crypto][-1]**2
# /Users/ephraim888sun/.pyenv/versions/3.9.6/lib/python3.9/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.003251. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /var/folders/sd/j5p08m515kd7n9549lkkz_q40000gn/T/ipykernel_65884/2994929627.py:29: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   forecast_errors[crypto] = forecast.variance.iloc[-1] - returns[crypto][-1]**2

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Convert dictionaries to DataFrame
aic_df = pd.DataFrame.from_dict(aic_values, orient='index', columns=['AIC'])
bic_df = pd.DataFrame.from_dict(bic_values, orient='index', columns=['BIC'])
std_df = pd.DataFrame.from_dict(residuals_std, orient='index', columns=['Std. Dev. of Residuals'])
adf_df = pd.DataFrame.from_dict(adf_pvalues, orient='index', columns=['ADF p-value'])
forecast_errors_df = pd.DataFrame.from_dict(forecast_errors, orient='index', columns=['Forecast Error'])

# Concatenate DataFrames
comparison_df = pd.concat([aic_df, bic_df, std_df, adf_df, forecast_errors_df], axis=1)

# Display DataFrame
print("Comparison of GARCH Model Analysis:")
print(comparison_df)

# Plot AIC and BIC values
plt.figure(figsize=(10, 6))
plt.plot(aic_df, label='AIC')
plt.plot(bic_df, label='BIC')
plt.title('Comparison of AIC and BIC Values')
plt.xlabel('Cryptocurrency')
plt.ylabel('Value')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# Plot Standard Deviation of Residuals
plt.figure(figsize=(10, 6))
plt.bar(std_df.index, std_df['Std. Dev. of Residuals'])
plt.title('Standard Deviation of Residuals for Cryptocurrencies')
plt.xlabel('Cryptocurrency')
plt.ylabel('Standard Deviation')
plt.xticks(rotation=45)
plt.show()

# Plot Augmented Dickey-Fuller Test p-values
plt.figure(figsize=(10, 6))
plt.bar(adf_df.index, adf_df['ADF p-value'])
plt.title('Augmented Dickey-Fuller Test p-values for Cryptocurrencies')
plt.xlabel('Cryptocurrency')
plt.ylabel('ADF p-value')
plt.xticks(rotation=45)
plt.show()

# Plot Forecast Errors
plt.figure(figsize=(10, 6))
plt.bar(forecast_errors_df.index, forecast_errors_df['Forecast Error'])
plt.title('Forecast Errors for Cryptocurrencies')
plt.xlabel('Cryptocurrency')
plt.ylabel('Forecast Error')
plt.xticks(rotation=45)
plt.show()
# Out:
# Comparison of GARCH Model Analysis:
#                   AIC          BIC  Std. Dev. of Residuals   ADF p-value  \
# BTC-USD  -1457.985088 -1442.396472                0.033262  0.000000e+00
# ETH-USD  -1238.843209 -1223.254594                0.045262  0.000000e+00
# SOL-USD  -1065.688513 -1050.099897                0.061336  0.000000e+00
# BNB-USD  -1376.050216 -1360.461601                0.037956  0.000000e+00
# XRP-USD  -1278.763975 -1263.175360                0.044616  8.920450e-19
# TON-USD  -1276.914733 -1261.326118                0.044813  2.030324e-30
# DOGE-USD -1140.649637 -1125.061021                0.056343  1.609525e-06
# ADA-USD  -1218.480958 -1202.892342                0.047766  1.217507e-08
# SHIB-USD -1014.427912  -998.839296                0.061631  2.032470e-19
# AVAX-USD -1100.705666 -1085.117051                0.057094  0.000000e+00
#
#          Forecast Error
# BTC-USD             NaN
# ETH-USD             NaN
# SOL-USD             NaN
# BNB-USD             NaN
# XRP-USD             NaN
# TON-USD             NaN
# DOGE-USD            NaN
# ADA-USD             NaN
# SHIB-USD            NaN
# AVAX-USD            NaN

# %% [markdown]
# When AIC (Akaike Information Criterion) and BIC (Bayesian Information Criterion) values are very close to each other and negative, it indicates that the GARCH model provides a good fit to the data. Both AIC and BIC are information criteria used for model selection, with lower values indicating a better fit.
#
# Here's what it means:
#
# Close Values: When AIC and BIC values are close to each other, it suggests that the model is not penalized much for complexity by using the BIC compared to the AIC. This is often observed when the sample size is large relative to the number of parameters estimated by the model.
#
# Negative Values: Both AIC and BIC can take negative values. Negative values are not inherently problematic and simply indicate the relative goodness of fit of the model. Lower (more negative) values indicate a better fit relative to other models being compared.
#
# Interpretation: In your case, an AIC value of -1457.985088 suggests that the GARCH model provides a very good fit to the data for the given cryptocurrency. The closeness of AIC and BIC values indicates that the model's complexity is adequately balanced with the goodness of fit, suggesting that it may be a suitable model for volatility forecasting for that particular cryptocurrency. However, it's essential to compare these values across different models and cryptocurrencies to make informed decisions about model selection.
